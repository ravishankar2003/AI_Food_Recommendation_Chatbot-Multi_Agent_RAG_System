# %%
import pandas as pd

# %%
df = pd.read_csv('restaurant_data_with_features.csv')

# %%
df
# Out:
#              r_id                 r_name           city  r_rating  \
# 0        567335.0         AB FOODS POINT         Abohar       1.9
# 1        567335.0         AB FOODS POINT         Abohar       2.0
# 2        567335.0         AB FOODS POINT         Abohar       2.7
# 3        567335.0         AB FOODS POINT         Abohar       2.0
# 4        567335.0         AB FOODS POINT         Abohar       1.3
# ...           ...                    ...            ...       ...
# 1063883   96525.0  IceBreakers Ice Cream  HSR,Bangalore       3.4
# 1063884   96525.0  IceBreakers Ice Cream  HSR,Bangalore       3.4
# 1063885   96525.0  IceBreakers Ice Cream  HSR,Bangalore       3.4
# 1063886   96525.0  IceBreakers Ice Cream  HSR,Bangalore       3.4
# 1063887   96525.0  IceBreakers Ice Cream  HSR,Bangalore       3.4
#
#          r_rating_count  avg_price_per_person             cuisine       f_id  \
# 0                    20                 200.0    Beverages,Pizzas        fd0
# ...

# %%
import pandas as pd

# Sample DataFrame creation (replace this with your actual data loading)
# df = pd.read_csv('your_data.csv')

# Split the cuisine column and create new columns
df[['cuisine_1', 'cuisine_2']] = df['cuisine'].str.split(',', n=1, expand=True)

# Remove any extra whitespace
df['cuisine_1'] = df['cuisine_1'].str.strip()
df['cuisine_2'] = df['cuisine_2'].str.strip()

# Display results
print(df.head())
# Out:
#        r_id          r_name    city  r_rating  r_rating_count  \
# 0  567335.0  AB FOODS POINT  Abohar       1.9              20
# 1  567335.0  AB FOODS POINT  Abohar       2.0              15
# 2  567335.0  AB FOODS POINT  Abohar       2.7              18
# 3  567335.0  AB FOODS POINT  Abohar       2.0              12
# 4  567335.0  AB FOODS POINT  Abohar       1.3              10
#
#    avg_price_per_person           cuisine      f_id  avg_price_per_item  \
# 0                 200.0  Beverages,Pizzas       fd0                40.0
# 1                 200.0  Beverages,Pizzas  fd669322                40.0
# 2                 200.0  Beverages,Pizzas       fd1                50.0
# 3                 200.0  Beverages,Pizzas       fd2                65.0
# 4                 200.0  Beverages,Pizzas       fd3                80.0
#
#                  f_name  ... HealthLabel  NewOrSeasonal  PromoIneligible  \
# 0     Aloo Tikki Burger  ...           0              0                0
# ...

# %%
df.to_csv('new.csv', index=False)
